# %% [markdown]
# # Data Tool Kit Assignment
# 1. What is NumPy, and why is it widely used in Python?
#     - NumPy (Numerical Python) is a powerful library for numerical computing in Python. It is widely used because it provides support for large multidimensional arrays, matrices, and a collection of mathematical functions to operate on these data structures efficiently.
#
# 2. How does broadcasting work in NumPy?
#     - Broadcasting allows NumPy to perform element-wise operations on arrays of different shapes without explicitly reshaping them. It automatically expands smaller arrays to match the shape of larger ones when performing operations.
#
# 3. What is a Pandas DataFrame?
#     - A Pandas DataFrame is a two-dimensional, tabular data structure with labeled axes (rows and columns). It is similar to a spreadsheet or SQL table and is used for data manipulation and analysis.
#
# 4. Explain the use of the groupby() method in Pandas.
#     - The groupby() method is used to group data based on a column or multiple columns. It enables aggregation functions like sum, mean, or count to be applied to each group separately.
#
# 5. Why is Seaborn preferred for statistical visualizations?
#     - Seaborn provides built-in themes and functions for statistical visualizations, making it easier to create visually appealing and informative graphs with minimal effort.
#
# 6. What are the differences between NumPy arrays and Python lists?
#
#     - NumPy arrays are more memory-efficient and faster for numerical computations.
#     - They support vectorized operations, whereas Python lists require explicit loops.
# NumPy arrays have fixed types, while Python lists can hold mixed data types.
#
# 7. What is a heatmap, and when should it be used?
#     - A heatmap is a graphical representation of data where values are represented by colors. It is used to show correlations, relationships, and patterns in data.
#
# 8. What does the term "vectorized operation" mean in NumPy?
#     - A vectorized operation is an operation applied to an entire array without explicit loops, making computations faster and more efficient.
#
# 9. How does Matplotlib differ from Plotly?
#
#     - Matplotlib is static and primarily used for 2D plotting.
# Plotly is interactive and supports advanced visualization, including 3D plots.
#
# 10. What is the significance of hierarchical indexing in Pandas?
#     - Hierarchical indexing allows multi-level indexing of rows and columns, making it easier to work with complex data.
#
# 11. What is the role of Seaborn’s pairplot() function?
#     - pairplot() creates pairwise scatterplots for numerical variables, helping to visualize relationships between multiple variables.
#
# 12. What is the purpose of the describe() function in Pandas?
#     - The describe() function provides summary statistics (mean, median, min, max, etc.) of numerical columns in a DataFrame.
#
# 13. Why is handling missing data important in Pandas?
#     - Missing data can lead to inaccurate analysis, so handling it (e.g., filling, dropping, or imputing values) ensures data integrity.
#
# 14. What are the benefits of using Plotly for data visualization?
#     - Plotly provides interactive and high-quality visualizations, supporting features like zooming, panning, and exporting.
#
# 15. How does NumPy handle multidimensional arrays?
#     - NumPy uses the ndarray object to handle multidimensional arrays efficiently, allowing operations like reshaping, slicing, and broadcasting.
#
# 16. What is the role of Bokeh in data visualization?
#     - Bokeh is a Python library for creating interactive and web-friendly visualizations.
#
# 17. Explain the difference between apply() and map() in Pandas.
#
#     - apply() is used for applying functions to rows or columns in a DataFrame.
#     - map() is used to apply functions element-wise to a Series.
# 18. What are some advanced features of NumPy?
#
#     - Broadcasting
#     - Vectorized operations
#     - Random number generation
#     - Linear algebra functions
#     - Fourier transforms
# 19. How does Pandas simplify time series analysis?
#     - Pandas provides built-in functions for handling time series, such as resampling, shifting, and date-time indexing.
#
# 20. What is the role of a pivot table in Pandas?
#     - A pivot table summarizes and reshapes data by aggregating values based on different categories.
#
# 21. Why is NumPy’s array slicing faster than Python’s list slicing?
#     - NumPy arrays store data in contiguous memory blocks, allowing efficient slicing and manipulation.
#
# 22. What are some common use cases for Seaborn?
#
#     - Statistical visualization
#     - Heatmaps for correlation matrices
#     - Pairwise scatterplots
#     - Boxplots for distribution analysis

# %%
# How do you create a 2D NumPy array and calculate the sum of each row
import numpy as np
arr = np.array([[1, 2, 3], [4, 5, 6]])
row_sum = arr.sum(axis=1)
print(row_sum)
# Out:
# [ 6 15]

# %%
# Write a Pandas script to find the mean of a specific column in a DataFrame
import pandas as pd
df = pd.DataFrame({'A': [1, 2, 3, 4], 'B': [5, 6, 7, 8]})
print(df['A'].mean())
# Out:
# 2.5

# %%
# Create a scatter plot using Matplotlib

import matplotlib.pyplot as plt
x = [1, 2, 3, 4]
y = [10, 20, 25, 30]
plt.scatter(x, y)
plt.show()

# %%
# How do you calculate the correlation matrix using Seaborn and visualize it with a heatmap

import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset
df = sns.load_dataset("iris")

# Compute correlation matrix (excluding non-numeric columns)
correlation_matrix = df.select_dtypes(include=['float64', 'int64']).corr()

# Create a heatmap
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# Generate a bar plot using Plotly

import plotly.express as px
df = px.data.gapminder().query("year == 2007")
fig = px.bar(df, x="continent", y="pop", title="Population by Continent")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Create a DataFrame and add a new column based on an existing column

df['C'] = df['A'] * 2
print(df)
# Out:
#    A  B  C
# 0  1  5  2
# 1  2  6  4
# 2  3  7  6
# 3  4  8  8

# %%
# Write a program to perform element-wise multiplication of two NumPy arrays

arr1 = np.array([1, 2, 3])
arr2 = np.array([4, 5, 6])
result = arr1 * arr2
print(result)
# Out:
# [ 4 10 18]

# %%
# Create a line plot with multiple lines using Matplotlib

plt.plot([1, 2, 3], [4, 5, 6], label="Line 1")
plt.plot([1, 2, 3], [6, 5, 4], label="Line 2")
plt.legend()
plt.show()

# %%
# Generate a Pandas DataFrame and filter rows where a column value is greater than a threshold

df_filtered = df[df['A'] > 2]
print(df_filtered)
# Out:
#    A  B  C
# 2  3  7  6
# 3  4  8  8

# %%
# Create a histogram using Seaborn to visualize a distribution

sns.histplot(df['A'], bins=10)
# Out:
# <Axes: xlabel='A', ylabel='Count'>

# %%
# Perform matrix multiplication using NumPy

mat1 = np.array([[1, 2], [3, 4]])
mat2 = np.array([[5, 6], [7, 8]])
result = np.dot(mat1, mat2)
print(result)
# Out:
# [[19 22]
#  [43 50]]

# %%
# Use Pandas to load a CSV file and display its first 5 rows

df = pd.read_csv("industry.csv")
print(df.head())
# Out:
#                         Industry
# 0             Accounting/Finance
# 1   Advertising/Public Relations
# 2             Aerospace/Aviation
# 3  Arts/Entertainment/Publishing
# 4                     Automotive

# %%
# Create a 3D scatter plot using Plotly.

fig = px.scatter_3d(df, x='A', y='B', z='C')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
